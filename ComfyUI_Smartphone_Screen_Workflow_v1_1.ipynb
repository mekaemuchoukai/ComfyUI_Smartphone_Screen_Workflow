# %%
# 1. Copy the ComfyUI files from GitHub.
# !git clone https://github.com/comfyanonymous/ComfyUI.git

# %%
# 1-2. Navigate to the ComfyUI folder.
# %cd ComfyUI

# %%
# 1-3. Start install
# !pip install -r requirements.txt

# %%
# 2. Installing the CheckPoint model (a learning model for image generation)
# %cd /content/ComfyUI/models/checkpoints
# !wget -O anima_pencil-XL.safetensors "https://civitai.com/api/download/models/597138?fileId=512255"

# %%
# 3. Installing the custom nodes
# Using "comfyui_controlnet_aux" makes it possible to extract line drawings.
# %cd /content/ComfyUI/custom_nodes
# !git clone https://github.com/Fannovel16/comfyui_controlnet_aux.git

# %cd comfyui_controlnet_aux !pip install -r requirements.txt

# %%
# 3-2. ComfyUI-RMBG Installing
# %cd /content/ComfyUI/custom_nodes
# !git clone https://github.com/1038lab/ComfyUI-RMBG.git
# %cd ComfyUI-RMBG
# !pip install -r requirements.txt

# %%
# 4. Installing controlnet
# "MistoLine" makes it possible to create images of different outfits from line drawings.
# %cd /content/ComfyUI/models/controlnet

# !wget -O mistoLine_rank256.safetensors "https://huggingface.co/TheMistoAI/MistoLine/resolve/main/mistoLine_rank256.safetensors?download=true"

# %%
# 5. Disconnect all connections before launching ComfyUI.
# An error will occur if the previous connection is still active.
# !lsof -i :8188
# !fuser -k 8188/tcp

# %%
# 6. Launching ComfyUI
# %cd /content/ComfyUI
# !python main.py --listen 0.0.0.0 --port 8188 --lowvram > comfyui.log 2>&1 &

# %%
# 7. Obtaining the global IP address of the current Colab environment
# !curl ipv4.icanhazip.com

# %%
# 8. Check the logs for any errors.
# !cat /content/ComfyUI/comfyui.log | tail -100

# %%
# 9. URL output
# This cell will remain running. Access the outputted URL. (This will not work in the Firefox browser.)
# !npm install -g localtunnel
# !lt --port 8188
